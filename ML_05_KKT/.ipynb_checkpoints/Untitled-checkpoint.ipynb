# %%
import numpy as np
import matplotlib.pyplot as plt
import mpl_toolkits.mplot3d.axes3d as p3

# %% [markdown]
# ## Lagrange Multiplier

# %% [markdown]
# $$
# \begin{array}{l}{max \ \ f(x, y)=x^{2} y} \\ {s.t. \ \ x^{2}+y^{2}=5}\end{array}
# $$

# %%
def f(x, y):
    return x**2 * y

x = np.linspace(-10, 10, 500)
y = np.linspace(-10, 10, 500)

X, Y = np.meshgrid(x,y)

Z = f(X, Y)

# %%
fig = plt.figure()
ax = plt.axes(projection='3d')


ax.plot_wireframe(X, Y, Z, color='black')
ax.set_title('wireframe');
ax.plot_surface(X, Y, Z, rstride=1, cstride=1,
                cmap='viridis', edgecolor='none')
ax.set_title('surface');

# %%
import plotly
import plotly.plotly as py
import plotly.figure_factory as ff
import plotly.graph_objs as go
plotly.tools.set_credentials_file(username='linchrisdeng', api_key='bpYfJmQg5fU1iu0Xf3j6')

# %%
x = np.linspace(-10, 10, 500)
y = np.linspace(-10, 10, 500)

X, Y = np.meshgrid(x,y)

Z = f(X, Y)

trace0 = go.Surface(
    x=X,
    y=Y,
    z=Z,
    opacity=0.9,
    showscale = False
)



data = [trace0]
layout = go.Layout(
    margin=dict(
        l=50,
        r=50,
        b=50,
        t=50
    )
)

# %%
fig = go.Figure(data=data, layout=layout)

py.iplot(fig, config=dict(displaylogo=False, showLink = False), filename='KKT_Model0')
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~linchrisdeng/67.embed" height="525px" width="100%"></iframe>

# %% [markdown]
# ## Contour plot

# %%
import plotly.plotly as py
import plotly.graph_objs as go

traceContour = go.Contour(
        z = Z,
        x = x,
        y = y,
        autocontour = False, 
        contours=dict(
            start = 500,
            end = -500,
            size = 5,
            coloring ='heatmap',
            showlabels = True,
            labelfont = dict(
                family = 'Raleway',
                size = 12,
                color = 'white',
            )
        )
    )


data = [traceContour]

py.iplot(data, filename = "KKT_Contour")
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~linchrisdeng/111.embed" height="525px" width="100%"></iframe>

# %%
trace2 = {
    "type": "cone",
    "x": X,
    "y": Y,
    "z": Z,
    "u": u,
    "v": v,
    "w": w,
    "colorscale": 'Blues',
    "sizemode": "absolute",
    "sizeref": 40
}

# %%
fig = go.Figure(data=data, layout=layout)

py.iplot(fig, config=dict(displaylogo=False, showLink = False), filename='KKT_Model1')
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~linchrisdeng/69.embed" height="525px" width="100%"></iframe>

# %%
x = np.linspace(-5, 5, 20)
y = np.linspace(-5, 5, 20)
X, Y = np.meshgrid(x,y)

u = 2*X*Y
v = X**2

fig = ff.create_quiver(X, Y, u, v,
                       scale=.05,
                       arrow_scale=.3,
                       name='quiver',
                       line=dict(width=1))

# %%
# traceGradient = ff.create_quiver(X, Y, u, v)
py.iplot(fig, filename =  "temp")
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~linchrisdeng/113.embed" height="525px" width="100%"></iframe>

# %%
x = np.linspace(-10, 10, 50)
y = np.linspace(-10, 10, 50)

X, Y = np.meshgrid(x,y)

Z = f(X, Y)
u = 2*X*Y
v = X**2

## Contour
fig, [ax0, ax1, ax2] = plt.subplots(1, 3, figsize = (30, 10))
level = np.unique(np.append(np.arange(-10, 10, 5), np.arange(-500, 500, 10)))
levels = np.sort(level)
mycmap = plt.get_cmap('seismic')
ax0.set_aspect('equal')
ax1.set_aspect('equal')
ax2.set_aspect('equal')

ax0.contour(cs, colors = 'black', alpha = 0.5)
cs = ax0.contourf(X, Y, Z, levels, cmap = mycmap)
ax0.clabel(cs, inline=10,fmt = '%d', fontsize=15, colors = 'k')

## Constrain
from matplotlib.patches import Circle
ax0.add_artist(Circle((0, 0), np.sqrt(5)))

## quiver
x1 = np.linspace(-5, 5, 20)
y1 = np.linspace(-5, 5, 20)
X1, Y1 = np.meshgrid(x1,y1)
u1 = 2*X1*Y1
v1 = X1**2
ax1.quiver(X1, Y1, u1, v1)

## Combine
ax2.contour(cs, colors = 'black', alpha = 0.5)
cs = ax2.contourf(X, Y, Z, levels, cmap = mycmap)
ax2.clabel(cs, inline=10,fmt = '%d', fontsize=15, colors = 'k')
ax2.quiver(X1, Y1, u1, v1)
ax2.add_artist(Circle((0, 0), np.sqrt(5)))
